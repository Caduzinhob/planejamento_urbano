# %% [markdown]
# # Visualização de Estatísticas do Grafo
# Este notebook permite carregar uma instância `.ins`, calcular as estatísticas do grafo e exibi-las em formato de tabela com `pandas`.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import os
from ler_arquivo import ler_arquivo_ins_arquivo
from calcular_estatisticas import calcular_estatisticas
from geracao_matriz import floyd_warshall

# %%
arquivo = [
    r"D:\Meus arquivos\Documentos\GitHub\planejamento_urbano\ins\09.ins"
]

# %%
caminho_exemplo = arquivo[0] 

grafo_exemplo = ler_arquivo_ins_arquivo(caminho_exemplo)
matriz_exemplo = floyd_warshall(grafo_exemplo)
estatisticas_exemplo = calcular_estatisticas(grafo_exemplo, matriz_exemplo)

df_exemplo = pd.DataFrame(estatisticas_exemplo.items(), columns=["Métrica", "Valor"])
display(df_exemplo.style.set_caption(f"📌 Estatísticas da Instância: {os.path.basename(caminho_exemplo)}").set_properties(**{'text-align': 'left'}))
# Out:
# <style type="text/css">
# #T_c26a4_row0_col0, #T_c26a4_row0_col1, #T_c26a4_row1_col0, #T_c26a4_row1_col1, #T_c26a4_row2_col0, #T_c26a4_row2_col1, #T_c26a4_row3_col0, #T_c26a4_row3_col1, #T_c26a4_row4_col0, #T_c26a4_row4_col1, #T_c26a4_row5_col0, #T_c26a4_row5_col1, #T_c26a4_row6_col0, #T_c26a4_row6_col1, #T_c26a4_row7_col0, #T_c26a4_row7_col1, #T_c26a4_row8_col0, #T_c26a4_row8_col1, #T_c26a4_row9_col0, #T_c26a4_row9_col1, #T_c26a4_row10_col0, #T_c26a4_row10_col1, #T_c26a4_row11_col0, #T_c26a4_row11_col1 {
#   text-align: left;
# }
# </style>
# <table id="T_c26a4">
#   <caption>📌 Estatísticas da Instância: 09.ins</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c26a4_level0_col0" class="col_heading level0 col0" >Métrica</th>
#       <th id="T_c26a4_level0_col1" class="col_heading level0 col1" >Valor</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c26a4_level0_row0" class="row_heading level0 row0" >0</th>
# ...

# %%
metricas_numericas = {k: v for k, v in estatisticas_exemplo.items() if isinstance(v, (int, float))}

plt.figure(figsize=(10, 6))
plt.bar(metricas_numericas.keys(), metricas_numericas.values(), color='skyblue')
plt.title("📊 Estatísticas da Instância 02.ins", fontsize=14)
plt.ylabel("Valor")
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.grid(axis='y', linestyle='--', alpha=0.6)
plt.show()
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_1424\2776764805.py:8: UserWarning: Glyph 128202 (\N{BAR CHART}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
